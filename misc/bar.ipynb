# %%
import time
#from tqdm.notebook import tqdm
from tqdm import tqdm

epoch = 1000
update_interval = 0.5  # seconds

# %%
bar = tqdm(total=epoch)
update_next = time.time()

for t in range(1,epoch+1):
    time.sleep(0.001)
    bar.update(1)

    current_time = time.time()
    if current_time > update_next:
        update_next = current_time + update_interval
        bar.set_postfix(loss="current loss here")

bar.close()
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 898.95it/s, loss=current loss here]

# %%
with tqdm(total=epoch) as bar:
    update_next = time.time()
    for t in range(1,epoch+1):
        time.sleep(0.001)
        bar.update(1)

        current_time = time.time()
        if current_time > update_next:
            update_next = current_time + update_interval
            bar.set_postfix(loss="current loss here")
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 929.93it/s, loss=current loss here]
